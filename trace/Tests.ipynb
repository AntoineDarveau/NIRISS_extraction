# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# # Plot lpsf

# %%
# Read from file

# with open('lpsf.txt','r') as file:
#     data=file.readlines()

data=np.loadtxt('lpsf.data')
data.shape
# Out:
# (64,)

# %%
plt.plot(data)

plt.xlabel('pixel?')

# %%
    bpix=np.float(1.0e30) #identifying bad pixels
    print(bpix)
# Out:
# 1e+30
